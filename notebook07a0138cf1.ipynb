# %%
# !git clone https://github.com/NTL-HUY/TrashCNN.git
# Out:
# Cloning into 'TrashCNN'...
# remote: Enumerating objects: 225, done.
# remote: Counting objects: 100% (225/225), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 225 (delta 101), reused 186 (delta 64), pack-reused 0 (from 0)
# Receiving objects: 100% (225/225), 18.55 MiB | 39.65 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
# %cd TrashCNN
# Out:
# /kaggle/working/TrashCNN

# %%
# !git checkout -b sub2 origin/sub2
# Out:
# Branch 'sub2' set up to track remote branch 'sub2' from 'origin'.
# Switched to a new branch 'sub2'

# %%
# !pip install faster-coco-eval torchmetrics torch torchvision

# %%
# !cp -r /kaggle/input/datasets/nhathuyzrv/taco-dataset/data /kaggle/working/TrashCNN

# %%
# !python train.py --num_epochs 100
# Out:
# 2026-05-06 13:37:44.966752: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778074665.182196      73 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778074665.238972      73 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778074665.727702      73 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
